# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR = '/content/gdrive/My Drive/Colab Notebooks'

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 kB 24.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
from google.colab import drive
import shutil

# Define la ruta de configuración y carga el modelo
model = YOLO("yolov8s.yaml")  # Crea un modelo nuevo desde cero

# Configura los parámetros de entrenamiento con early stopping
results = model.train(
    data=os.path.join(ROOT_DIR, "google_colab_config.yaml"),
    epochs=300,  # Máximo número de epochs
    patience=20  # Detén si no mejora en 10 epochs consecutivos
)

# Copia los resultados al Google Drive
drive.mount('/content/drive')
shutil.copytree('/content/runs', '/content/drive/My Drive/Colab Notebooks/run25_11')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.37 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
